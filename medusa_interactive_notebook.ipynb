# %%
# %config IPCompleter.use_jedi = False
# %pdb off
# %load_ext autoreload
# %autoreload 3


# ==================================================================================================================================================================================================================================================================================== #
# PyQtInspect:                                                                                                                                                                                                                                                                         #
# ==================================================================================================================================================================================================================================================================================== #
# 1. Launch `pqi-server` in a new terminal BEFORE running this notebook cell. Be sure to click 'Serve' button in the GUI that appears so this notebook can connect.

# IMPORTANT: Call settrace BEFORE importing PyQt5
import PyQtInspect.pqi as pqi

# Connect to the server (default: localhost:19394)
# Make sure the server is already running!
pqi.settrace(
    host='127.0.0.1',
    port=19394,  # Default port, or use the port shown in the server GUI
    qt_support='auto',  # or 'auto' for auto-detection
    patch_multiprocessing=False
)


# %matplotlib inline
# %matplotlib qt5
# import mne
# mne.viz.set_browser_backend("qt")  # or "matplotlib"
# mne.set_config("MNE_BROWSER_BACKEND", "qt")  # or "matplotlib"
# %gui qt

# import IPython

# # Jupyter-lab enable printing for any line on its own (instead of just the last one in the cell)
# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_interactivity = "all"


import sys
# Path to the folder that contains constants.py (package root)
sys.path.insert(0, r"C:\Users\pho\repos\EmotivEpoc\ACTIVE_DEV\medusa-platform\src\medusa_platform")




# Now this can work
from medusa_platform.gui.main_window import GuiMainClass

# from medusa_platform import *
# # import medusa_platform as medusa

# # import medusa_platform.gui
# # import medusa_platform.gui as gui

# from medusa_platform.gui.main_window import GuiMainClass
from PySide6.QtWidgets import QApplication
import sys
# Out:
# Automatic pdb calling has been turned OFF
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Traceback (most recent call last):
#   File "C:\Users\pho\repos\EmotivEpoc\ACTIVE_DEV\medusa-platform\src\medusa_platform\gui\lsl_config\lsl_config.py", line 366, in __init__
#     self.init_widgets()
#     ~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\pho\repos\EmotivEpoc\ACTIVE_DEV\medusa-platform\src\medusa_platform\gui\lsl_config\lsl_config.py", line 402, in init_widgets
#     self.on_read_channels_info()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\pho\repos\EmotivEpoc\ACTIVE_DEV\medusa-platform\src\medusa_platform\gui\lsl_config\lsl_config.py", line 580, in on_read_channels_info
#     self.update_cha_label()
#     ~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\pho\repos\EmotivEpoc\ACTIVE_DEV\medusa-platform\src\medusa_platform\gui\lsl_config\lsl_config.py", line 681, in update_cha_label
#     self.update_channels_table()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\pho\repos\EmotivEpoc\ACTIVE_DEV\medusa-platform\src\medusa_platform\gui\lsl_config\lsl_config.py", line 684, in update_channels_table
#     self.update_cha_info_dict()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\pho\repos\EmotivEpoc\ACTIVE_DEV\medusa-platform\src\medusa_platform\gui\lsl_config\lsl_config.py", line 650, in update_cha_info_dict
#     ch_label = ch['label'].upper()
#                ~~^^^^^^^^^
# KeyError: 'label'
# Traceback (most recent call last):
#   File "C:\Users\pho\repos\EmotivEpoc\ACTIVE_DEV\medusa-platform\src\medusa_platform\gui\lsl_config\lsl_config.py", line 366, in __init__
#     self.init_widgets()
#     ~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\pho\repos\EmotivEpoc\ACTIVE_DEV\medusa-platform\src\medusa_platform\gui\lsl_config\lsl_config.py", line 402, in init_widgets
#     self.on_read_channels_info()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\pho\repos\EmotivEpoc\ACTIVE_DEV\medusa-platform\src\medusa_platform\gui\lsl_config\lsl_config.py", line 580, in on_read_channels_info
#     self.update_cha_label()
#     ~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\pho\repos\EmotivEpoc\ACTIVE_DEV\medusa-platform\src\medusa_platform\gui\lsl_config\lsl_config.py", line 681, in update_cha_label
#     self.update_channels_table()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\pho\repos\EmotivEpoc\ACTIVE_DEV\medusa-platform\src\medusa_platform\gui\lsl_config\lsl_config.py", line 684, in update_channels_table
#     self.update_cha_info_dict()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\pho\repos\EmotivEpoc\ACTIVE_DEV\medusa-platform\src\medusa_platform\gui\lsl_config\lsl_config.py", line 650, in update_cha_info_dict
#     ch_label = ch['label'].upper()
#                ~~^^^^^^^^^
# KeyError: 'label'
# Traceback (most recent call last):
#   File "C:\Users\pho\repos\EmotivEpoc\ACTIVE_DEV\medusa-platform\src\medusa_platform\gui\lsl_config\lsl_config.py", line 366, in __init__
#     self.init_widgets()
#     ~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\pho\repos\EmotivEpoc\ACTIVE_DEV\medusa-platform\src\medusa_platform\gui\lsl_config\lsl_config.py", line 402, in init_widgets
#     self.on_read_channels_info()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\pho\repos\EmotivEpoc\ACTIVE_DEV\medusa-platform\src\medusa_platform\gui\lsl_config\lsl_config.py", line 580, in on_read_channels_info
#     self.update_cha_label()
#     ~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\pho\repos\EmotivEpoc\ACTIVE_DEV\medusa-platform\src\medusa_platform\gui\lsl_config\lsl_config.py", line 681, in update_cha_label
#     self.update_channels_table()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\pho\repos\EmotivEpoc\ACTIVE_DEV\medusa-platform\src\medusa_platform\gui\lsl_config\lsl_config.py", line 684, in update_channels_table
#     self.update_cha_info_dict()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~^^
#   File "C:\Users\pho\repos\EmotivEpoc\ACTIVE_DEV\medusa-platform\src\medusa_platform\gui\lsl_config\lsl_config.py", line 650, in update_cha_info_dict
#     ch_label = ch['label'].upper()
#                ~~^^^^^^^^^
# KeyError: 'label'

# %%
from PySide6.QtWidgets import QApplication
import sys

# Use existing app if %gui qt already created one, else create it
app = QApplication.instance() or QApplication(sys.argv)
main_window = GuiMainClass()
main_window.show()
# Do NOT call app.exec() — %gui qt runs the event loop; calling exec() would block the kernel
# Out:
# Failed to read module file 'C:\Users\pho\repos\EmotivEpoc\ACTIVE_DEV\medusa-platform\src\medusa_platform\gui\lsl_config\channel_selection_dialogs.py' for module 'gui.lsl_config.channel_selection_dialogs': UnicodeDecodeError
# Traceback (most recent call last):
#   File "c:\Users\pho\repos\EmotivEpoc\ACTIVE_DEV\medusa-platform\.venv\Lib\site-packages\IPython\extensions\deduperreload\deduperreload.py", line 219, in update_sources
#     self.source_by_modname[new_modname] = f.read()
#                                           ~~~~~~^^
#   File "C:\Users\pho\.pyenv\pyenv-win\versions\3.13.12\Lib\encodings\cp1252.py", line 23, in decode
#     return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#            ~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 11258: character maps to <undefined>

# %%
main_window
# Out:
# <medusa_platform.gui.main_window.GuiMainClass(0x1d874474570, name="MainWindow") at 0x000001D8776C51C0>
